   1.090000      0.3160300    
   1.190000      0.2933000    
   1.290000      0.2722400    
   1.390000      0.2527100    
   1.490000      0.2346000    
   1.590000      0.2177800    
   1.690000      0.2021600    
   1.790000      0.1876500    
   1.890000      0.1741800    
   1.990000      0.1616600    
   2.090000      0.1500400    
   2.190000      0.1392400    
   2.290000      0.1292100    
   2.390000      0.1198900    
   2.490000      0.1112400    
   2.590000      0.1032000    
   2.690000      9.5739998E-02
   2.790000      8.8809997E-02
   2.890000      8.2379997E-02
   2.990000      7.6410003E-02
   3.090000      7.0869997E-02
   3.190000      6.5729998E-02
   3.290000      6.0950000E-02
   3.390000      5.6520000E-02
   3.490000      5.2409999E-02
   3.590000      4.8590001E-02
   3.690000      4.5049999E-02
   3.790000      4.1770000E-02
   3.890000      3.8720001E-02
   3.990000      3.5900000E-02
   4.090000      3.3280000E-02
   4.190000      3.0850001E-02
   4.290000      2.8589999E-02
   4.390000      2.6500000E-02
   4.490000      2.4569999E-02
   4.590000      2.2770001E-02
   4.690000      2.1100000E-02
   4.790000      1.9560000E-02
   4.890000      1.8120000E-02
   4.990000      1.6790001E-02
   5.090000      1.5560000E-02
   5.190000      1.4420000E-02
   5.290000      1.3360000E-02
"""

def parse_data_block(data_block):
    energies = []
    probabilities = []
    for line in data_block.strip().split('\n'):
        parts = line.strip().split()
        if len(parts) == 2:
            try:
                energy = float(parts[0])
                prob = float(parts[1])
                energies.append(energy)
                probabilities.append(prob)
            except ValueError:
                pass  # Ignore any line that cannot be parsed
    return np.array(energies), np.array(probabilities)

# Remplacer les "..." par le reste des données ou lire à partir d'un fichier texte
energies_861, flux_861 = parse_data_block(data_861)
energies_384, flux_384 = parse_data_block(data_384)

energies_861 = (energies_861 + 861.3)*10**(-3)
energies_384 = (energies_384 +384.3)*10**(-3)

integral384  = trapezoid(flux_384,energies_384) #On vérifie la normalisation
integral861  = trapezoid(flux_861,energies_861) #On vérifie la normalisation


flux_861 = flux_861*4.8*10**9
flux_384 = flux_384*4.8*10**9


# Plot
plt.figure(figsize=(10, 6))
plt.plot(energies_861, flux_861, label="7 Be - 1", color='blue')
plt.plot(energies_384, flux_384, label="7 Be - 2", color='orange')
plt.title("Flux (cm-2.s-1.MeV-1)")
plt.xlabel("Énergie (MeV)")
plt.ylabel("Flux (cm-2.s-1.MeV-1)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#         b. 8B

# %%
import numpy as np
import matplotlib.pyplot as plt
  
input_file = "../dataflux/8B.dat"

# Initialiser les colonnes
energy8B = []
spectrum_best8B = []

with open(input_file, 'r') as file:
    for line in file:
        parts = line.strip().split()
        if len(parts) == 4:
            e, best, plus3, minus3 = parts
            energy8B.append(float(e))
            spectrum_best8B.append(float(best)*(5*10**6))

integral  = trapezoid(spectrum_best8B,energy8B) #On vérifie la normalisation


# Plot
plt.figure(figsize=(10, 6))
plt.plot(energy8B , spectrum_best8B, label="8 B", color='blue')
plt.title("Flux de 8B => 2(4He) + e+ + v")
plt.xlabel("Énergie (MeV)")
plt.ylabel("Flux (cm-2.s-1.MeV-1)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#         c. 13N

# %%
input_file = "../dataflux/13N.dat"

# Initialiser les colonnes
energy13N = []
spectrum_best13N = []

with open(input_file, 'r') as file:
    for line in file:
        parts = line.strip().split()
        if len(parts) == 2:
            e, best = parts
            energy13N.append(float(e))
            spectrum_best13N.append(float(best)*2.9*10**8)

integral  = trapezoid(spectrum_best13N,energy13N) #On vérifie la normalisation

# Plot
plt.figure(figsize=(10, 6))
plt.plot(energy13N , spectrum_best13N, label="13 N", color='blue')
plt.title("Flux de 13N => 13C + e+ + v")
plt.xlabel("Énergie (MeV)")
plt.ylabel("Flux (cm-2.s-1.MeV-1)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#         d. 15O

# %%
input_file = "../dataflux/15O.dat"

# Initialiser les colonnes
energy15O = []
spectrum_best15O = []

with open(input_file, 'r') as file:
    for line in file:
        parts = line.strip().split()
        if len(parts) == 2:
            e, best = parts
            energy15O.append(float(e))
            spectrum_best15O.append(float(best)*2.3*10**8)

integral  = trapezoid(spectrum_best15O,energy15O) #On vérifie la normalisation



# Plot
plt.figure(figsize=(10, 6))
plt.plot(energy15O , spectrum_best15O, label="15 O", color='blue')
plt.title("Flux de 15O => 15N + e+ + v")
plt.xlabel("Énergie (MeV)")
plt.ylabel("Flux (cm-2.s-1.MeV-1)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#         e. 17F

# %%
input_file = "../dataflux/17F.dat"

# Initialiser les colonnes
energy17F = []
spectrum_best17F = []

with open(input_file, 'r') as file:
    for line in file:
        parts = line.strip().split()
        if len(parts) == 2:
            e, best = parts
            energy17F.append(float(e))
            spectrum_best17F.append(float(best)*5.6*10**6)

integral  = trapezoid(spectrum_best17F,energy17F) #On vérifie la normalisation

# Plot
plt.figure(figsize=(10, 6))
plt.plot(energy17F , spectrum_best17F, label="17 F", color='blue')
plt.title("Flux de 17F => 17O + e+ + v")
plt.xlabel("Énergie (MeV)")
plt.ylabel("Flux (cm-2.s-1.MeV-1)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#         f. pp

# %%
input_file = "../dataflux/pp.dat"

# Initialiser les colonnes
energy1 = []
energy2 = []
energy3 = []
energy4 = []
spectrum_best1 = []
spectrum_best2 = []
spectrum_best3 = []
spectrum_best4 = []

with open(input_file, 'r') as file:
    for line in file:
        parts = line.strip().split()
        if len(parts) == 8:
            e1, best1, e2, best2, e3, best3, e4, best4 = parts
            energy1.append(float(e1) )
            energy2.append(float(e2) )
            energy3.append(float(e3) )
            energy4.append(float(e4) )
            spectrum_best1.append(float(best1)*6*10**10)
            spectrum_best2.append(float(best2)*6*10**10)
            spectrum_best3.append(float(best3)*6*10**10)
            spectrum_best4.append(float(best4)*6*10**10)

energypp = (energy1 + energy2 + energy3 + energy4) 
spectrum_bestpp = (spectrum_best1 + spectrum_best2 + spectrum_best3 + spectrum_best4) 

integral  = trapezoid(spectrum_bestpp,energypp) #On vérifie la normalisation


# Plot
plt.figure(figsize=(10, 6))
plt.plot(energypp , spectrum_bestpp, label="pp", color='blue')
plt.title("Flux de p + p => 2H + e+ + v")
plt.xlabel("Énergie (MeV)")
plt.ylabel("Flux (cm-2.s-1.MeV-1)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#         g. hep

# %%
input_file = "../dataflux/hep.dat"

# Initialiser les colonnes
energyhep = []
spectrum_besthep = []

with open(input_file, 'r') as file:
    for line in file:
        parts = line.strip().split()
        if len(parts) == 2:
            e, best = parts
            energyhep.append(float(e))
            spectrum_besthep.append(float(best)*8*10**3)

integral  = trapezoid(spectrum_besthep,energyhep) #On vérifie la normalisation


# Plot
plt.figure(figsize=(10, 6))
plt.plot(energyhep , spectrum_besthep, label="hep", color='blue')
plt.title("Flux de 3He + p => 4He + e+ + v")
plt.xlabel("Énergie (MeV)")
plt.ylabel("Flux (cm-2.s-1.MeV-1)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from scipy.interpolate import interp1d
import pandas as pd

plt.figure(figsize=(10, 6))


#7Be
plt.plot((energies_861), (flux_861), label="7 Be - 1", color='blue')
plt.plot((energies_384), (flux_384), label="7 Be - 2", color='blue')
#8B
plt.plot((energy8B) , (spectrum_best8B), label="8 B", color='green')
#13N
plt.plot((energy13N) , (spectrum_best13N), "--", label="13 N",  color='black')
#15O
plt.plot((energy15O), (spectrum_best15O), "--",label="15 O",  color='black')
#17F
plt.plot((energy17F) , (spectrum_best17F), "--",label="17 F", color='black')
#pp
plt.plot((energypp) , (spectrum_bestpp), label="pp", color='red')
#hep
plt.plot((energyhep) , (spectrum_besthep), label="hep", color='orange')

#Total Flux

arbitrary_energy = np.linspace(0.05, 30, 1000) #On créer un tableau de valeurs d'énergies entre 10**-2 et 10**2 avec 1000 points

# 2. Interpoler tous les flux sur cette grille
interp_flux1 = interp1d(energies_861, flux_861, bounds_error=False, fill_value=0)
interp_flux2 = interp1d(energies_384, flux_384, bounds_error=False, fill_value=0)
interp_flux3 = interp1d(energy8B, spectrum_best8B, bounds_error=False, fill_value=0)
interp_flux4 = interp1d(energy13N, spectrum_best13N, bounds_error=False, fill_value=0)
interp_flux5 = interp1d(energy15O, spectrum_best15O, bounds_error=False, fill_value=0)
interp_flux6 = interp1d(energy17F, spectrum_best17F, bounds_error=False, fill_value=0)
interp_flux7 = interp1d(energypp, spectrum_bestpp, bounds_error=False, fill_value=0)
interp_flux8 = interp1d(energyhep, spectrum_besthep, bounds_error=False, fill_value=0)





# 3. Somme des flux interpolés
total_flux = interp_flux1(arbitrary_energy) + interp_flux2(arbitrary_energy) + interp_flux3(arbitrary_energy)  + interp_flux4(arbitrary_energy) + interp_flux5(arbitrary_energy) + interp_flux6(arbitrary_energy) + interp_flux7(arbitrary_energy) + interp_flux8(arbitrary_energy)

total_fluxB8hep = interp_flux3(arbitrary_energy) + interp_flux8(arbitrary_energy)

integral = trapezoid(total_flux,arbitrary_energy)

print(len(arbitrary_energy))

plt.plot(arbitrary_energy,total_flux, ":",label='Total flux', color='black')
#plt.plot(arbitrary_energy,interp_flux1(arbitrary_energy) , label='7Be', color= 'black')
# plt.plot(arbitrary_energy,interp_flux3(arbitrary_energy), label='8B', color= 'blue')
# plt.plot(arbitrary_energy,interp_flux4(arbitrary_energy), label='13N', color= 'orange')
# plt.plot(arbitrary_energy,interp_flux5(arbitrary_energy), label='15O', color= 'orange')
# plt.plot(arbitrary_energy,interp_flux6(arbitrary_energy), label='17F', color= 'orange')
# plt.plot(arbitrary_energy,interp_flux7(arbitrary_energy), label='pp', color= 'red')
# plt.plot(arbitrary_energy,interp_flux8(arbitrary_energy), label='hep', color= 'green')

plt.title("Solar Neutrino fluxes VS Neutrino Energy")
plt.xlabel(r"Neutrino Energy $E_\nu$ [MeV]")
plt.ylabel(r"$\frac{d\phi}{dE_\nu}$ [cm$^{-2}$.s$^{-1}$.MeV$^{-1}$]")
plt.xscale('log')
plt.yscale('log')
plt.xlim(0.05,30)

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

df_total_flux = pd.DataFrame({
    "Energy [MeV]": arbitrary_energy,
    "Total Flux [cm⁻²·s⁻¹·MeV⁻¹]": total_flux
})

# Afficher un aperçu
print(df_total_flux.head())

# Sauvegarder en CSV si besoin
df_total_flux.to_csv("total_solar_flux.csv", index=False)
# Out:
# 1000
#    Energy [MeV]  Total Flux [cm⁻²·s⁻¹·MeV⁻¹]
# 0       0.05000                 1.830315e+10
# 1       0.07998                 4.289698e+10
# 2       0.10996                 7.387527e+10
# 3       0.13994                 1.083146e+11
# 4       0.16992                 1.435111e+11
